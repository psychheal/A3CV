# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Install dependencies**

# %%
# !pip install -U -q segmentation-models
#!pip uninstall tensorflow
# !pip install tensorflow==2.7
#!pip install tensorflow==2.6.0
#!pip install keras==2.6.0
# Out:
#      |████████████████████████████████| 50 kB 7.2 MB/s
# Collecting tensorflow==2.7
#   Downloading tensorflow-2.7.0-cp37-cp37m-manylinux2010_x86_64.whl (489.6 MB)
#      |████████████████████████████████| 489.6 MB 21 kB/s
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (3.17.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (0.2.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (3.1.0)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 37.6 MB/s
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 55.0 MB/s
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (14.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (0.25.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (0.37.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.15.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.46.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (3.3.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.21.6)
# Collecting gast<0.5.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (4.2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.7) (1.0.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow==2.7) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.7) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7) (3.2.0)
# Installing collected packages: tensorflow-estimator, keras, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0+zzzcolab20220506162203
#     Uninstalling tensorflow-2.8.0+zzzcolab20220506162203:
#       Successfully uninstalled tensorflow-2.8.0+zzzcolab20220506162203
# Successfully installed gast-0.4.0 keras-2.7.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0

# %% [markdown]
# **Import Libraries**

# %%
import os
os.environ['TF_KERAS'] = '1'
from skimage import color
import tensorflow as tf
import segmentation_models as sm
import glob
from tensorflow.keras.layers import *
from keras.applications.vgg16 import VGG16
from keras.utils.vis_utils import plot_model
from keras.layers import Flatten
import cv2
import os
from matplotlib import pyplot as plt
import keras 
from tensorflow.keras.utils import normalize
from keras.metrics import MeanIoU
import numpy as np
from skimage.transform import AffineTransform, warp
from keras.models import load_model
import torchvision.models as models
from skimage import io, img_as_ubyte
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.layers import *
import random
import numpy as np 
import os
import numpy as np
from tensorflow.python.keras.models import *
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.optimizers import *
from tensorflow.python.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.python.keras import backend as K
from tensorflow.python.keras import utils
import tensorflow.keras as keras
from random import randint,choice
from scipy.ndimage import rotate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
from tensorflow.python.keras.models import *
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.optimizers import *
from tensorflow.python.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.python.keras import backend as K
from tensorflow.python.keras import utils
import tensorflow.keras as keras
from natsort import natsorted
from tensorflow.keras.models import Sequential,  Model
from keras import Sequential, layers
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D,BatchNormalization,Add,GlobalAveragePooling2D,UpSampling2D

# %% [markdown]
# **Functions for measuring accuracies**

# %%
epsilon = 1e-5
def iou_coef1(y_true, y_pred):
  intersection = K.sum((y_true * y_pred))
  union = K.sum(y_true)+K.sum(y_pred)-intersection
  iou = K.mean((intersection) / (union))
  return iou
def dice_coef( y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + K.epsilon()) / (
                    K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())
def f1( y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        v1 =  K.sum(y_true_f) / intersection
        v2 =  K.sum(y_pred_f)/ intersection
        return (2+ K.epsilon()) / (
                   v1 + v2 + K.epsilon())        
def sensitivity( y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        return true_positives / (possible_positives + K.epsilon())
        
def specificity( y_true, y_pred):
        true_negatives = K.sum(
            K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
        possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
        return true_negatives / (possible_negatives + K.epsilon())

# %% [markdown]
# **Data augmentation using custom data augmentation functions**

# %%
def rotation(image, seed):
    random.seed(seed)
    angle= random.randint(-180,180)
    rotated_img = rotate(image, angle, mode='reflect', reshape=False, order=0)
    return rotated_img

def h_flip(image, seed):
    hflipped_img= np.fliplr(image)
    return  hflipped_img

def v_flip(image, seed):
    vflipped_img= np.flipud(image)
    return vflipped_img

def v_transl(image, seed):
    random.seed(seed)
    n_pixels = random.randint(-64,64)
    vtranslated_img = np.roll(image, n_pixels, axis=0)
    return vtranslated_img

def h_transl(image, seed):
    random.seed(seed)
    n_pixels = random.randint(-64,64)
    htranslated_img = np.roll(image, n_pixels, axis=1)
    return htranslated_img
seed_for_random = 7
transformations = {'rotate': rotation,
                    'horizontal flip': h_flip, 
                    'vertical flip': v_flip,
                   'vertical shift': v_transl,
                   'horizontal shift': h_transl
                 }               

images_path="/content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train" #path to original images
masks_path ="/content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train" #path to original masks
img_augmented_path="/content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train" # path to store aumented images
msk_augmented_path="/content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train"# path to store aumented masks
images=[] # to store paths of images from folder
masks=[]

for im in os.listdir(images_path):  # read image name from folder and append its path into "images" array     
    images.append(os.path.join(images_path,im))

for msk in os.listdir(masks_path):  # read image name from folder and append its path into "images" array     
    masks.append(os.path.join(masks_path,msk))

i=0   # variable to iterate till images_to_generate
#iterate over all images
while i<367: 
    image = images[i]
    mask = masks[i]
    original_image = io.imread(image)
    original_mask = io.imread(mask)
    transformed_image = None
    transformed_mask = None
    key = np.random.choice(list(transformations)) #randomly choosing method to call
    print(key)
    seed = random.randint(1,100)  #Generate seed to supply transformation functions. 
    transformed_image = transformations[key](original_image, seed)
    transformed_mask = transformations[key](original_mask, seed)
    new_image_path= "%s/augmented_image_%s.png" %(img_augmented_path, i)
    new_mask_path = "%s/augmented_mask_%s.png" %(msk_augmented_path, i)   #Do not save as JPG
    io.imsave(new_image_path, transformed_image)
    io.imsave(new_mask_path, transformed_mask)
    i =i+1
# Out:
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_0.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_1.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_2.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_3.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_4.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_5.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_6.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_7.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_8.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_9.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_10.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_11.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_12.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_13.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_14.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_15.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_16.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_17.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_18.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_19.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_20.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_21.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_22.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_23.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_24.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_25.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_26.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_27.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_28.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_29.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_30.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_31.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_32.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_33.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_34.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_35.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_36.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_37.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_38.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_39.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_40.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_41.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_42.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_43.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_44.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_45.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_46.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_47.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_48.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_49.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_50.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_51.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_52.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_53.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_54.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_55.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_56.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_57.png is a low contrast image
# vertical flip
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_58.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_59.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_60.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_61.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_62.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_63.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_64.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_65.png is a low contrast image
# rotate
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_66.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_67.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_68.png is a low contrast image
# horizontal flip
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_69.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_70.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_71.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_72.png is a low contrast image
# horizontal shift
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_73.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_74.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_75.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_76.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_77.png is a low contrast image
# horizontal flip
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_78.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_79.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_80.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_81.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_82.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_83.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_84.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_85.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_86.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_87.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_88.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_89.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_90.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_91.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_92.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_93.png is a low contrast image
# horizontal flip
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_94.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_95.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_96.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_97.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_98.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_99.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_100.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_101.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_102.png is a low contrast image
# vertical flip
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_103.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_104.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_105.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_106.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_107.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_108.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_109.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_110.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_111.png is a low contrast image
# horizontal flip
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_112.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_113.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_114.png is a low contrast image
# horizontal shift
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_115.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_116.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_117.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_118.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_119.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_120.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_121.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_122.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_123.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_124.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_125.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_126.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_127.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_128.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_129.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_130.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_131.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_132.png is a low contrast image
# horizontal shift
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_133.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_134.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_135.png is a low contrast image
# vertical shift
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_136.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_137.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_138.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_139.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_140.png is a low contrast image
# horizontal flip
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_141.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_142.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_143.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_144.png is a low contrast image
# horizontal shift
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_145.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_146.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_147.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_148.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_149.png is a low contrast image
# horizontal shift
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_150.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_151.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_152.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_153.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_154.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_155.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_156.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_157.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_158.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_159.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_160.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_161.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_162.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_163.png is a low contrast image
# horizontal shift
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_164.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_165.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_166.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_167.png is a low contrast image
# horizontal flip
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_168.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_169.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_170.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_171.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_172.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_173.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_174.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_175.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_176.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_177.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_178.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_179.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_180.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_181.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_182.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_183.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_184.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_185.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_186.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_187.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_188.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_189.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_190.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_191.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_192.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_193.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_194.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_195.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_196.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_197.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_198.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_199.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_200.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_201.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_202.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_203.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_204.png is a low contrast image
# horizontal shift
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_205.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_206.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_207.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_208.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_209.png is a low contrast image
# vertical flip
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_210.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_211.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_212.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_213.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_214.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_215.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_216.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_217.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_218.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_219.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_220.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_221.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_222.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_223.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_224.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_225.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_226.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_227.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_228.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_229.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_230.png is a low contrast image
# horizontal shift
# ...
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_290.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_291.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_292.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_293.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_294.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_295.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_296.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_297.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_298.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_299.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_300.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_301.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_302.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_303.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_304.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_305.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_306.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_307.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_308.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_309.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_310.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_311.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_312.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_313.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_314.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_315.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_316.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_317.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_318.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_319.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_320.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_321.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_322.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_323.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_324.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_325.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_326.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_327.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_328.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_329.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_330.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_331.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_332.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_333.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_334.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_335.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_336.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_337.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_338.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_339.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_340.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_341.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_342.png is a low contrast image
# vertical flip
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_343.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_344.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_345.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_346.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_347.png is a low contrast image
# horizontal flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_348.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_349.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_350.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_351.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_352.png is a low contrast image
# vertical flip
# horizontal shift
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_353.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_354.png is a low contrast image
# vertical flip
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_355.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_356.png is a low contrast image
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_357.png is a low contrast image
# horizontal flip
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_358.png is a low contrast image
# vertical shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_359.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_360.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_361.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_362.png is a low contrast image
# horizontal shift
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_363.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_364.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_365.png is a low contrast image
# rotate
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: UserWarning: /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_366.png is a low contrast image

# %% [markdown]
# **Functions for reading images and masks**

# %%
def readImages(path):
  #names array reads the names of the files and sort them in ascending order by using natsorted library
  #this sorting is required because cv2.imread reads images randomly so some masks doesn't corresponds to their respective images
  names = []
  images = []
  # x and y defines the height and width size of the newly resized images so convolutions can be applied easily
  x = 128
  y = 128
  # this loop reads the names of the image files and stores them in names list
  for directory_path in glob.glob(path):
    for name_path in glob.glob(os.path.join(directory_path, "*.png")):
        names.append(name_path)
  names = natsorted(names)  
  # this loop reads the images in ascending order to ensure every mask matches their respective image
  for i in range(len(names)):
        #imgs.append(img_path)
        img = cv2.imread(names[i], 1)       
        print(names[i] + " img")
        img = cv2.resize(img, (x, y))
        #plt.imshow(img)
        images.append(img)     
#Convert list to array for machine learning processing        
  images = np.array(images)
  return images 
def readMasks(path):
  #names array reads the names of the files and sort them in ascending order by using natsorted library
  #this sorting is required because cv2.imread reads images randomly so some masks doesn't corresponds to their respective images
  names = []
  masks = []
  # x and y defines the height and width size of the newly resized images so convolutions can be applied easily
  x = 128
  y = 128
  # this loop reads the names of the image files and stores them in names list
  for directory_path in glob.glob(path):
    for name_path in glob.glob(os.path.join(directory_path, "*.png")):
        names.append(name_path)
  names = natsorted(names)  
  # this loop reads the images in ascending order to ensure every mask matches their respective image
  for i in range(len(names)):
        #imgs.append(img_path)
        msk = cv2.imread(names[i], 0)       
        print(names[i] + " mask")
        msk = cv2.resize(msk, (x, y), interpolation = cv2.INTER_NEAREST)
        #plt.imshow(img)
        masks.append(msk)     
#Convert list to array for machine learning processing        
  masks = np.array(masks)
  return masks
#As mask consist of various classes of object for each pixel therefore, each class is a category thus we convert mask classes to OHE  
def oneHotEncoder(imagesMasks):
  n_classes = 12
  #imagesMasks = readImages("/content/drive/MyDrive/dataset1 - Copy/annotations_prepped_train/")
  labelencoder = LabelEncoder()
  n, h, w = imagesMasks.shape
  masks_reshaped = imagesMasks.reshape(-1,1)
  masks_reshaped_encoded = labelencoder.fit_transform(masks_reshaped)
  masks_encoded_original_shape = masks_reshaped_encoded.reshape(n, h, w)

  np.unique(masks_encoded_original_shape)
  train_masks_input = np.expand_dims(masks_encoded_original_shape, axis=3)
  train_masks_cat = to_categorical(train_masks_input, num_classes=n_classes)
  y_train_cat = train_masks_cat.reshape((train_masks_input.shape[0], train_masks_input.shape[1], train_masks_input.shape[2], n_classes))
  return y_train_cat

# %% [markdown]
# **Custom Resnet50 with Atrous Spatial Pyramid Pooling layers**

# %%
def identity_block(input_x, filters):
    
    filters_1, filters_2, filters_3 = filters

    x = Conv2D(filters_1, (1, 1))(input_x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters_2, 3,padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters_3, (1, 1))(x)
    x = BatchNormalization()(x)
    
    x = add([x, input_x])
    x = Activation('relu')(x)
    return x


def conv_block(input_x, filters, strides=(2, 2)):

    filters_1, filters_2, filters_3 = filters



    x = Conv2D(filters_1, (1, 1), strides=strides)(input_x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters_2, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters_3, (1, 1))(x)
    x = BatchNormalization()(x)

    shortcut = Conv2D(filters_3, (1, 1),
                      strides=strides)(input_x)
    shortcut = BatchNormalization()(shortcut)


    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x


def resnet50_encoder(pretrained_weights = 'imagenet', num_classes = 20, input_size = (256,256,1)):

    pretrained_url = "https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5"

    inp = Input(input_size)

    x = ZeroPadding2D((3, 3))(inp)
    x = Conv2D(64, (7, 7),
               strides=(2, 2))(x)
    feature_map_1 = x

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2))(x)

    x = conv_block(x, [64, 64, 256], strides=(1, 1))
    x = identity_block(x, [64, 64, 256])
    x = identity_block(x, [64, 64, 256])
    feature_map_2 = ZeroPadding2D((1, 1))(x)
    feature_map_2 = Lambda(lambda x: x[:, :-1, :-1, :])(feature_map_2)

    x = conv_block(x, [128, 128, 512])
    x = identity_block(x, [128, 128, 512])
    x = identity_block(x, [128, 128, 512])
    x = identity_block(x, [128, 128, 512])
    feature_map_3 = x

    x = conv_block(x, [256, 256, 1024])
    x = identity_block(x,  [256, 256, 1024])
    x = identity_block(x,  [256, 256, 1024])
    x = identity_block(x,  [256, 256, 1024])
    x = identity_block(x,  [256, 256, 1024])
    x = identity_block(x,  [256, 256, 1024])
    feature_map_4 = x

    x = conv_block(x, [512, 512, 2048])
    x = identity_block(x, [512, 512, 2048])
    x = identity_block(x, [512, 512, 2048])
    feature_map_5 = x




    model = Model(inputs = inp, outputs = feature_map_5)


    if pretrained_weights == 'imagenet':
        weights_path = tf.keras.utils.get_file(pretrained_url.split("/")[-1], pretrained_url)
        model.load_weights(weights_path)

    return inp,[feature_map_1,feature_map_2,feature_map_3,feature_map_4,feature_map_5]

def resnet50_encoder_unet_decoder(pretrained_weights = None, num_classes = 12, input_size = (128,128,3)):
    inp, feature_map_list= resnet50_encoder(pretrained_weights = 'imagenet', num_classes = num_classes, input_size = input_size)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same')(UpSampling2D(size = (2,2))(feature_map_list[4]))
    merge6 = concatenate([feature_map_list[3],up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same')(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([feature_map_list[2],up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same')(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([feature_map_list[1],up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same')(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([feature_map_list[0],up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same')(conv9)
    
    up10 = Conv2D(64, 2, activation = 'relu', padding = 'same')(UpSampling2D(size = (2,2))(conv9))
    merge9 = concatenate([inp,up10], axis = 3)
    conv10 = Conv2D(64, 3, activation = 'relu', padding = 'same')(merge9)
    conv10 = Conv2D(64, 3, activation = 'relu', padding = 'same')(conv10)
    out = Conv2D(64, (1, 1), dilation_rate=2)(conv10)
    #ASPP layers
    atrous_rates = (6, 12, 18)
    x = conv10
    b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
    b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
    b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
    x = Concatenate()([b1, b2, b3])
    merge10= concatenate([x, conv10], axis = 3)
    conv11 = Conv2D(12, 1, activation = 'softmax')(merge10)
    print(merge10.shape)
    model = Model(inputs = inp, outputs = conv11)

    model.compile(optimizer = 'adam', loss = total_loss, metrics =metrics)
    if(pretrained_weights):
        model.load_weights(pretrained_weights)
    print(model.summary())
    plot_model(model, show_shapes=True, to_file='multichanne2.png')
    return model
 
def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
 
    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation('relu')(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)

    return x

# %% [markdown]
# **Function for displaying training  graphs**

# %%
def trainingGraph(history_):
  loss = history_.history['loss']
  #val_loss = history_.history['val_loss']
  epochs = range(0, len(loss))
  plt.plot(epochs, loss, 'y', label='Training loss')
  #plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()

  acc = history_.history['iou_score']
  #val_acc = history_.history['val_iou_score']

  plt.plot(epochs, acc, 'y', label='Training IOU')
  #plt.plot(epochs, val_acc, 'r', label='Validation IOU')
  plt.title('Training IOU')
  plt.xlabel('Epochs')
  plt.ylabel('IOU')
  plt.legend()
  plt.show()

# %% [markdown]
# **metric for model**

# %%
#n_classes=12
#activation='softmax'
#LR = 0.0001
#modelOptimizer = tf.keras.optimizers.Adam(LR)
# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss (car: 1.; pedestrian: 2.; background: 0.5;)
dice_loss = sm.losses.DiceLoss(class_weights=np.array([0.083, 0.083, 0.083, 0.083,0.083,0.083,0.083,0.083,0.083,0.083,0.083,0.083])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)
  # actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
  # total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 
metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5), "accuracy", dice_coef ]

# %% [markdown]
# **Function for displaying predicted mask along with original mask and  overlapped mask on original image**

# %%
def correct_Incorrect(models, testing_images, y_masks,testingMasks, test_img_number, model):
 # preprocess_input = sm.get_preprocessing(models)
  test_img_number = test_img_number
  test_img = testing_images[test_img_number]
  ground_truth=y_masks[test_img_number]
  test_img_input=np.expand_dims(test_img, 0)
  #test_img_input1 = preprocess_input(test_img_input)
  test_pred1 = model.predict(test_img_input)
  test_prediction1 = np.argmax(test_pred1, axis=3)[0,:,:]
  result_image1 = color.label2rgb(test_prediction1, testing_images[test_img_number])
  result_image = color.label2rgb(testingMasks[test_img_number],test_img )
  plt.figure(figsize=(12, 12))
  plt.subplot(231)
  plt.title('Testing Image')
  plt.imshow(test_img[:,:,0])
  plt.subplot(232)
  plt.title('Testing Label')
  plt.imshow(testingMasks[test_img_number])
  plt.subplot(233)
  plt.title('Prediction on test image')
  plt.imshow(test_prediction1)
  plt.show()
  return result_image1, result_image
def overlay(image, caption):
    plt.title(caption)
    plt.imshow(image) 
    plt.show()

# %% [markdown]
# **Function for displaying the model prediction measures on test dataset**

# %%
def testMetrics(models, testing_imgs,y_masks):
  dice_coefficient_test = []
  f1_score_test = []
  sensitivity_test =[]  
  specificity_test = []
  accuracy_iou = []
  preprocess_input = sm.get_preprocessing(models)
  for i in range(101):
    test_img_number = i
    test_img = testing_imgs[test_img_number]
    ground_truth=y_masks[test_img_number]
    test_img_input=np.expand_dims(test_img, 0)
    test_img_input1 = preprocess_input(test_img_input)
    #test_pred1 = model.predict(test_img_input1)
    y_test = model.predict(test_img_input1)
    test_mask=ground_truth.astype(np.float32)
    f1_score_test.append(K.eval(f1(test_mask, y_test)))
    accuracy_iou.append(K.eval(iou_coef1(test_mask, y_test)))
    dice_coefficient_test.append(K.eval(dice_coef(test_mask, y_test)))
    sensitivity_test.append(K.eval(sensitivity(test_mask,y_test)))
    specificity_test.append(K.eval(specificity(test_mask,y_test)))
    
  print ("average of Dice Coefficient, Sensitivity, Specificity,f1-score, iou accuracy", sum(dice_coefficient_test) / 101, sum(sensitivity_test)/ 101, sum(specificity_test)/ 101, sum(f1_score_test)/ 101, sum(accuracy_iou) /101)

# %% [markdown]
# **Training function for getting training data**

# %%
def training(imgpath, maskpath):
  training_imgs = readImages(imgpath)
  training_masks = readMasks(maskpath)
  y_masks = oneHotEncoder(training_masks)
  return training_imgs, y_masks,training_masks

# %%
def testing(imgpath, maskpath):
  training_imgs = readImages(imgpath)
  training_masks = readMasks(maskpath)
  y_masks = oneHotEncoder(training_masks)
  return training_imgs, y_masks,training_masks

# %%
trainimgPath = "/content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train"
trainmaskPath = "/content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train"
training_imgs,y_masks, trainingMsks = training(trainimgPath,trainmaskPath)
# Out:
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (1).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (2).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (3).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (4).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (5).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (6).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (7).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (8).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (9).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (10).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (11).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (12).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (13).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (14).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (15).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (16).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (17).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (18).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (19).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (20).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (21).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (22).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (23).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (24).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (25).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (26).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (27).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (28).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (29).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (30).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (31).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (32).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (33).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (34).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (35).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (36).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (37).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (38).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (39).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (40).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (41).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (42).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (43).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (44).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (45).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (46).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (47).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (48).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (49).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (50).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (51).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (52).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (53).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (54).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (55).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (56).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (57).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (58).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (59).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (60).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (61).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (62).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (63).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (64).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (65).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (66).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (67).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (68).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (69).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (70).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (71).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (72).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (73).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (74).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (75).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (76).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (77).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (78).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (79).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (80).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (81).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (82).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (83).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (84).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (85).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (86).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (87).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (88).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (89).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (90).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (91).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (92).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (93).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (94).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (95).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (96).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (97).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (98).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (99).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (100).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (101).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (102).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (103).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (104).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (105).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (106).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (107).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (108).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (109).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (110).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (111).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (112).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (113).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (114).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (115).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (116).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (117).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (118).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (119).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (120).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (121).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (122).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (123).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (124).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (125).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (126).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (127).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (128).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (129).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (130).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (131).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (132).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (133).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (134).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (135).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (136).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (137).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (138).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (139).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (140).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (141).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (142).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (143).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (144).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (145).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (146).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (147).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (148).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (149).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (150).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (151).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (152).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (153).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (154).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (155).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (156).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (157).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (158).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (159).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (160).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (161).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (162).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (163).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (164).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (165).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (166).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (167).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (168).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (169).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (170).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (171).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (172).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (173).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (174).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (175).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (176).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (177).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (178).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (179).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (180).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (181).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (182).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (183).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (184).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (185).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (186).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (187).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (188).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (189).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (190).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (191).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (192).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (193).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (194).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (195).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (196).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (197).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (198).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (199).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (200).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (201).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (202).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (203).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (204).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (205).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (206).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (207).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (208).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (209).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (210).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (211).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (212).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (213).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (214).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (215).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (216).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (217).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (218).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (219).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (220).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (221).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (222).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (223).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (224).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (225).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (226).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (227).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (228).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (229).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (230).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (231).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (232).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (233).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (234).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (235).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (236).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (237).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (238).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (239).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (240).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (241).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (242).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (243).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (244).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (245).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (246).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (247).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (248).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (249).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (250).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (251).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (252).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (253).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (254).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (255).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (256).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (257).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (258).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (259).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (260).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (261).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (262).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (263).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (264).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (265).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (266).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (267).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (268).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (269).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (270).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (271).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (272).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (273).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (274).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (275).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (276).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (277).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (278).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (279).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (280).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (281).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (282).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (283).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (284).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (285).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (286).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (287).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (288).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (289).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (290).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (291).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (292).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (293).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (294).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (295).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (296).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (297).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (298).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (299).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (300).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (301).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (302).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (303).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (304).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (305).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (306).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (307).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (308).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (309).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (310).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (311).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (312).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (313).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (314).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (315).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (316).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (317).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (318).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (319).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (320).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (321).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (322).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (323).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (324).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (325).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (326).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (327).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (328).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (329).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (330).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (331).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (332).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (333).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (334).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (335).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (336).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (337).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (338).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (339).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (340).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (341).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (342).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (343).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (344).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (345).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (346).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (347).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (348).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (349).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (350).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (351).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (352).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (353).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (354).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (355).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (356).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (357).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (358).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (359).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (360).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (361).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (362).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (363).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (364).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (365).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (366).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/1 (367).png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_0.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_1.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_2.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_3.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_4.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_5.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_6.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_7.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_8.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_9.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_10.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_11.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_12.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_13.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_14.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_15.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_16.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_17.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_18.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_19.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_20.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_21.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_22.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_23.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_24.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_25.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_26.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_27.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_28.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_29.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_30.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_31.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_32.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_33.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_34.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_35.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_36.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_37.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_38.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_39.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_40.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_41.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_42.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_43.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_44.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_45.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_46.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_47.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_48.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_49.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_50.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_51.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_52.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_53.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_54.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_55.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_56.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_57.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_58.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_59.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_60.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_61.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_62.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_63.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_64.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_65.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_66.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_67.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_68.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_69.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_70.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_71.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_72.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_73.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_74.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_75.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_76.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_77.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_78.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_79.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_80.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_81.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_82.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_83.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_84.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_85.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_86.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_87.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_88.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_89.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_90.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_91.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_92.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_93.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_94.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_95.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_96.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_97.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_98.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_99.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_100.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_101.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_102.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_103.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_104.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_105.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_106.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_107.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_108.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_109.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_110.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_111.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_112.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_113.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_114.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_115.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_116.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_117.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_118.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_119.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_120.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_121.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_122.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_123.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_124.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_125.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_126.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_127.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_128.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_129.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_130.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_131.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_132.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_133.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_134.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_135.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_136.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_137.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_138.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_139.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_140.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_141.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_142.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_143.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_144.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_145.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_146.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_147.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_148.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_149.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_150.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_151.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_152.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_153.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_154.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_155.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_156.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_157.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_158.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_159.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_160.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_161.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_162.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_163.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_164.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_165.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_166.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_167.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_168.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_169.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_170.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_171.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_172.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_173.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_174.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_175.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_176.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_177.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_178.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_179.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_180.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_181.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_182.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_183.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_184.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_185.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_186.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_187.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_188.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_189.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_190.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_191.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_192.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_193.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_194.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_195.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_196.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_197.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_198.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_199.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_200.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_201.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_202.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_train/augmented_image_203.png img
# ...
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_205.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_206.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_207.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_208.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_209.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_210.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_211.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_212.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_213.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_214.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_215.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_216.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_217.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_218.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_219.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_220.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_221.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_222.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_223.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_224.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_225.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_226.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_227.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_228.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_229.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_230.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_231.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_232.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_233.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_234.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_235.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_236.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_237.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_238.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_239.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_240.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_241.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_242.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_243.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_244.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_245.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_246.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_247.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_248.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_249.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_250.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_251.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_252.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_253.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_254.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_255.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_256.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_257.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_258.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_259.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_260.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_261.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_262.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_263.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_264.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_265.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_266.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_267.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_268.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_269.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_270.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_271.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_272.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_273.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_274.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_275.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_276.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_277.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_278.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_279.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_280.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_281.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_282.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_283.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_284.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_285.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_286.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_287.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_288.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_289.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_290.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_291.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_292.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_293.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_294.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_295.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_296.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_297.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_298.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_299.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_300.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_301.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_302.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_303.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_304.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_305.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_306.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_307.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_308.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_309.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_310.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_311.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_312.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_313.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_314.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_315.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_316.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_317.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_318.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_319.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_320.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_321.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_322.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_323.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_324.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_325.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_326.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_327.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_328.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_329.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_330.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_331.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_332.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_333.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_334.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_335.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_336.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_337.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_338.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_339.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_340.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_341.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_342.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_343.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_344.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_345.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_346.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_347.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_348.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_349.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_350.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_351.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_352.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_353.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_354.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_355.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_356.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_357.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_358.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_359.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_360.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_361.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_362.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_363.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_364.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_365.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_train/augmented_mask_366.png mask
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
trainingMsks.shape
# Out:
# (734, 128, 128)

# %% [markdown]
# **RESNET 50 With ASPP Model Initilization**

# %%
model2   = resnet50_encoder_unet_decoder(pretrained_weights = None, num_classes = 12, input_size = (128,128,3))
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 134, 134, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 31, 31, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 31, 31, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 31, 31, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 31, 31, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 31, 31, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 31, 31, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 31, 31, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 31, 31, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 31, 31, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 31, 31, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 31, 31, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 31, 31, 256)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 31, 31, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 31, 31, 64)   16448       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 31, 31, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 31, 31, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 31, 31, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 31, 31, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 31, 31, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 31, 31, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 31, 31, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 31, 31, 256)  0           batch_normalization_7[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 31, 31, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 31, 31, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 31, 31, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 31, 31, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 31, 31, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 31, 31, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 31, 31, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 31, 31, 256)  16640       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 31, 31, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 31, 31, 256)  0           batch_normalization_10[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 31, 31, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  32896       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 512)  66048       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 512)  131584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 512)  0           batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  65664       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 512)  66048       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 512)  2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 512)  0           batch_normalization_17[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 128)  65664       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 512)  66048       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 512)  2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 512)  0           batch_normalization_20[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 128)  65664       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 128)  512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 128)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 512)  66048       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 512)  2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 512)  0           batch_normalization_23[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 256)    131328      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 256)    1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 1024)   263168      activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 1024)   525312      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 1024)   4096        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 1024)   4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 1024)   0           batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 1024)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    262400      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 256)    590080      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 256)    1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 256)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 1024)   263168      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 1024)   4096        conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 1024)   0           batch_normalization_30[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 256)    262400      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 256)    1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 256)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 256)    590080      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 256)    1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 256)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 1024)   263168      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 1024)   4096        conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 1024)   0           batch_normalization_33[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 1024)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 256)    262400      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 256)    1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 256)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 256)    590080      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 256)    1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 256)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 1024)   263168      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 1024)   4096        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 1024)   0           batch_normalization_36[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 1024)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 256)    262400      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 256)    1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 256)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 256)    590080      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 256)    1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 256)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 1024)   263168      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 1024)   4096        conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 1024)   0           batch_normalization_39[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 1024)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 256)    262400      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 256)    1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 256)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 256)    590080      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 256)    1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 256)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 1024)   263168      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 1024)   4096        conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 1024)   0           batch_normalization_42[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 1024)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 4, 4, 512)    524800      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 512)    2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 4, 4, 512)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 4, 4, 512)    2359808     activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 512)    2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 4, 512)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 2048)   1050624     activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 2048)   2099200     activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 2048)   8192        conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 2048)   8192        conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 2048)   0           batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 4, 4, 2048)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 512)    1049088     activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 512)    2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 4, 512)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 512)    2359808     activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 512)    2048        conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 4, 512)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 2048)   1050624     activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 4, 4, 2048)   8192        conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 2048)   0           batch_normalization_49[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 4, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 512)    1049088     activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 4, 4, 512)    2048        conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 4, 512)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 512)    2359808     activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 4, 4, 512)    2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 512)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 2048)   1050624     activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 4, 4, 2048)   8192        conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 2048)   0           batch_normalization_52[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 8, 8, 2048)   0           activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 512)    4194816     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 1536)   0           activation_39[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 512)    7078400     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_54[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 512)  0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 768)  0           activation_21[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_57[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 33, 33, 256)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32, 32, 256)  0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 128)  131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 384)  0           lambda[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 128)  442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 128)  0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 64)   32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 128)  0           conv2d[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_63[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64) 0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 128, 128, 64) 16448       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 67) 0           input_1[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise (DepthwiseConv2 (None, 128, 128, 67) 603         concatenate_4[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise (DepthwiseConv2 (None, 128, 128, 67) 603         concatenate_4[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise (DepthwiseConv2 (None, 128, 128, 67) 603         concatenate_4[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise_BN (BatchNormal (None, 128, 128, 67) 268         aspp1_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise_BN (BatchNormal (None, 128, 128, 67) 268         aspp2_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise_BN (BatchNormal (None, 128, 128, 67) 268         aspp3_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 128, 128, 67) 0           aspp1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 128, 128, 67) 0           aspp2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 128, 128, 67) 0           aspp3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise (Conv2D)        (None, 128, 128, 3)  201         activation_49[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise (Conv2D)        (None, 128, 128, 3)  201         activation_51[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise (Conv2D)        (None, 128, 128, 3)  201         activation_53[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_BN (BatchNormal (None, 128, 128, 3)  12          aspp1_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_BN (BatchNormal (None, 128, 128, 3)  12          aspp2_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_BN (BatchNormal (None, 128, 128, 3)  12          aspp3_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128, 128, 3)  0           aspp1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 128, 128, 3)  0           aspp2_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 128, 128, 3)  0           aspp3_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 9)  0           activation_50[0][0]
#                                                                  activation_52[0][0]
#                                                                  activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 128, 128, 64) 5248        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 128, 128, 12) 780         conv2d_67[0][0]
# ==================================================================================================
# Total params: 41,032,576
# Trainable params: 40,979,036
# Non-trainable params: 53,540
# __________________________________________________________________________________________________
# None

# %%
history2= model2.fit(training_imgs, 
          y_masks,
          batch_size=32, 
          epochs=50)
#model2.save('res34_backbone_50epochs2.hdf5')
tf.saved_model.save(model2, 'saved_model')
# Out:
# Epoch 1/50
# 12/12 [==============================] - 392s 32s/step - loss: 1.0230 - iou_score: 0.0425 - f1-score: 0.0542 - accuracy: 0.4274 - dice_coef: 0.2196
# Epoch 2/50
# 12/12 [==============================] - 378s 31s/step - loss: 1.0047 - iou_score: 0.1369 - f1-score: 0.1588 - accuracy: 0.6373 - dice_coef: 0.4617
# Epoch 3/50
# 12/12 [==============================] - 381s 31s/step - loss: 0.9946 - iou_score: 0.1889 - f1-score: 0.2135 - accuracy: 0.7016 - dice_coef: 0.5891
# Epoch 4/50
# 12/12 [==============================] - 377s 31s/step - loss: 0.9896 - iou_score: 0.2155 - f1-score: 0.2454 - accuracy: 0.7368 - dice_coef: 0.6404
# Epoch 5/50
# 12/12 [==============================] - 381s 32s/step - loss: 0.9851 - iou_score: 0.2460 - f1-score: 0.2855 - accuracy: 0.7712 - dice_coef: 0.6830
# Epoch 6/50
# 12/12 [==============================] - 376s 31s/step - loss: 0.9795 - iou_score: 0.3172 - f1-score: 0.3760 - accuracy: 0.8137 - dice_coef: 0.7376
# Epoch 7/50
# 12/12 [==============================] - 376s 31s/step - loss: 0.9746 - iou_score: 0.3613 - f1-score: 0.4204 - accuracy: 0.8425 - dice_coef: 0.7738
# Epoch 8/50
# 12/12 [==============================] - 376s 31s/step - loss: 0.9733 - iou_score: 0.3689 - f1-score: 0.4272 - accuracy: 0.8441 - dice_coef: 0.7842
# Epoch 9/50
# 12/12 [==============================] - 374s 31s/step - loss: 0.9709 - iou_score: 0.3860 - f1-score: 0.4426 - accuracy: 0.8558 - dice_coef: 0.8028
# Epoch 10/50
# 12/12 [==============================] - 374s 31s/step - loss: 0.9690 - iou_score: 0.3982 - f1-score: 0.4533 - accuracy: 0.8629 - dice_coef: 0.8097
# Epoch 11/50
# 12/12 [==============================] - 374s 31s/step - loss: 0.9668 - iou_score: 0.4192 - f1-score: 0.4798 - accuracy: 0.8716 - dice_coef: 0.8246
# Epoch 12/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9657 - iou_score: 0.4323 - f1-score: 0.4964 - accuracy: 0.8747 - dice_coef: 0.8302
# Epoch 13/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9649 - iou_score: 0.4361 - f1-score: 0.5017 - accuracy: 0.8762 - dice_coef: 0.8314
# Epoch 14/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9633 - iou_score: 0.4519 - f1-score: 0.5216 - accuracy: 0.8797 - dice_coef: 0.8375
# Epoch 15/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9613 - iou_score: 0.4800 - f1-score: 0.5598 - accuracy: 0.8838 - dice_coef: 0.8482
# Epoch 16/50
# 12/12 [==============================] - 376s 31s/step - loss: 0.9604 - iou_score: 0.4879 - f1-score: 0.5714 - accuracy: 0.8841 - dice_coef: 0.8509
# Epoch 17/50
# 12/12 [==============================] - 373s 31s/step - loss: 0.9591 - iou_score: 0.5043 - f1-score: 0.5932 - accuracy: 0.8862 - dice_coef: 0.8549
# Epoch 18/50
# 12/12 [==============================] - 373s 31s/step - loss: 0.9581 - iou_score: 0.5117 - f1-score: 0.6032 - accuracy: 0.8885 - dice_coef: 0.8590
# Epoch 19/50
# 12/12 [==============================] - 374s 31s/step - loss: 0.9573 - iou_score: 0.5235 - f1-score: 0.6218 - accuracy: 0.8889 - dice_coef: 0.8595
# Epoch 20/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9574 - iou_score: 0.5284 - f1-score: 0.6291 - accuracy: 0.8881 - dice_coef: 0.8594
# Epoch 21/50
# 12/12 [==============================] - 373s 31s/step - loss: 0.9540 - iou_score: 0.5582 - f1-score: 0.6631 - accuracy: 0.8966 - dice_coef: 0.8699
# Epoch 22/50
# 12/12 [==============================] - 374s 31s/step - loss: 0.9520 - iou_score: 0.5775 - f1-score: 0.6844 - accuracy: 0.8999 - dice_coef: 0.8737
# Epoch 23/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9510 - iou_score: 0.5858 - f1-score: 0.6928 - accuracy: 0.9030 - dice_coef: 0.8786
# Epoch 24/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9496 - iou_score: 0.5981 - f1-score: 0.7056 - accuracy: 0.9053 - dice_coef: 0.8807
# Epoch 25/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9502 - iou_score: 0.5923 - f1-score: 0.7005 - accuracy: 0.9033 - dice_coef: 0.8783
# Epoch 26/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9490 - iou_score: 0.6040 - f1-score: 0.7104 - accuracy: 0.9062 - dice_coef: 0.8822
# Epoch 27/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9478 - iou_score: 0.6159 - f1-score: 0.7238 - accuracy: 0.9079 - dice_coef: 0.8845
# Epoch 28/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9473 - iou_score: 0.6217 - f1-score: 0.7278 - accuracy: 0.9094 - dice_coef: 0.8875
# Epoch 29/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9458 - iou_score: 0.6367 - f1-score: 0.7407 - accuracy: 0.9140 - dice_coef: 0.8937
# Epoch 30/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9456 - iou_score: 0.6406 - f1-score: 0.7448 - accuracy: 0.9135 - dice_coef: 0.8927
# Epoch 31/50
# 12/12 [==============================] - 373s 31s/step - loss: 0.9443 - iou_score: 0.6536 - f1-score: 0.7558 - accuracy: 0.9183 - dice_coef: 0.8997
# Epoch 32/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9432 - iou_score: 0.6646 - f1-score: 0.7655 - accuracy: 0.9210 - dice_coef: 0.9021
# Epoch 33/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9433 - iou_score: 0.6643 - f1-score: 0.7652 - accuracy: 0.9208 - dice_coef: 0.9021
# Epoch 34/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9426 - iou_score: 0.6707 - f1-score: 0.7718 - accuracy: 0.9219 - dice_coef: 0.9034
# Epoch 35/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9421 - iou_score: 0.6764 - f1-score: 0.7765 - accuracy: 0.9241 - dice_coef: 0.9066
# Epoch 36/50
# 12/12 [==============================] - 371s 31s/step - loss: 0.9417 - iou_score: 0.6814 - f1-score: 0.7804 - accuracy: 0.9251 - dice_coef: 0.9081
# Epoch 37/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9416 - iou_score: 0.6834 - f1-score: 0.7833 - accuracy: 0.9237 - dice_coef: 0.9059
# Epoch 38/50
# 12/12 [==============================] - 373s 31s/step - loss: 0.9412 - iou_score: 0.6867 - f1-score: 0.7854 - accuracy: 0.9252 - dice_coef: 0.9098
# Epoch 39/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9407 - iou_score: 0.6924 - f1-score: 0.7912 - accuracy: 0.9267 - dice_coef: 0.9105
# Epoch 40/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9400 - iou_score: 0.7015 - f1-score: 0.7987 - accuracy: 0.9281 - dice_coef: 0.9121
# Epoch 41/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9398 - iou_score: 0.7039 - f1-score: 0.8004 - accuracy: 0.9293 - dice_coef: 0.9136
# Epoch 42/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9395 - iou_score: 0.7053 - f1-score: 0.8018 - accuracy: 0.9302 - dice_coef: 0.9145
# Epoch 43/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9392 - iou_score: 0.7088 - f1-score: 0.8053 - accuracy: 0.9302 - dice_coef: 0.9148
# Epoch 44/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9388 - iou_score: 0.7150 - f1-score: 0.8100 - accuracy: 0.9317 - dice_coef: 0.9174
# Epoch 45/50
# 12/12 [==============================] - 372s 31s/step - loss: 0.9383 - iou_score: 0.7203 - f1-score: 0.8139 - accuracy: 0.9333 - dice_coef: 0.9185
# Epoch 46/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9381 - iou_score: 0.7221 - f1-score: 0.8163 - accuracy: 0.9341 - dice_coef: 0.9203
# Epoch 47/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9381 - iou_score: 0.7229 - f1-score: 0.8172 - accuracy: 0.9341 - dice_coef: 0.9205
# Epoch 48/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9380 - iou_score: 0.7205 - f1-score: 0.8153 - accuracy: 0.9343 - dice_coef: 0.9197
# Epoch 49/50
# 12/12 [==============================] - 370s 31s/step - loss: 0.9381 - iou_score: 0.7196 - f1-score: 0.8150 - accuracy: 0.9337 - dice_coef: 0.9190
# Epoch 50/50
# 12/12 [==============================] - 368s 31s/step - loss: 0.9392 - iou_score: 0.7085 - f1-score: 0.8064 - accuracy: 0.9306 - dice_coef: 0.9165
# INFO:tensorflow:Assets written to: saved_model/assets

# %%
trainingGraph(history2)

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/resnet50_atrous.hdf5', compile=False)

# %%
testPath = "/content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test"
testmaskPath = "/content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test"
testing_imgs,testingy_masks, testingMsks = testing(testPath,testmaskPath)
# Out:
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07959.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07961.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07963.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07965.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07967.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07969.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07971.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07973.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07975.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07977.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07979.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07981.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07983.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07985.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07987.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07989.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07991.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07993.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07995.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07997.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_07999.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08001.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08003.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08005.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08007.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08009.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08011.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08013.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08015.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08017.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08019.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08021.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08023.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08025.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08027.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08029.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08031.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08033.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08035.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08037.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08039.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08041.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08043.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08045.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08047.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08049.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08051.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08053.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08055.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08057.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08059.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08061.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08063.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08065.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08067.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08069.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08071.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08073.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08075.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08077.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08079.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08081.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08083.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08085.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08087.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08089.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08091.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08093.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08095.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08097.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08099.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08101.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08103.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08105.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08107.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08109.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08111.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08113.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08115.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08117.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08119.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08121.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08123.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08125.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08127.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08129.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08131.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08133.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08135.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08137.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08139.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08141.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08143.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08145.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08147.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08149.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08151.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08153.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08155.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08157.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/images_prepped_test/0016E5_08159.png img
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07959.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07961.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07963.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07965.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07967.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07969.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07971.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07973.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07975.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07977.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07979.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07981.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07983.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07985.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07987.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07989.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07991.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07993.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07995.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07997.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_07999.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08001.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08003.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08005.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08007.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08009.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08011.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08013.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08015.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08017.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08019.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08021.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08023.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08025.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08027.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08029.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08031.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08033.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08035.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08037.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08039.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08041.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08043.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08045.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08047.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08049.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08051.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08053.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08055.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08057.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08059.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08061.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08063.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08065.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08067.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08069.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08071.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08073.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08075.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08077.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08079.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08081.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08083.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08085.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08087.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08089.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08091.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08093.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08095.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08097.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08099.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08101.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08103.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08105.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08107.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08109.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08111.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08113.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08115.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08117.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08119.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08121.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08123.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08125.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08127.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08129.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08131.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08133.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08135.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08137.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08139.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08141.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08143.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08145.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08147.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08149.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08151.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08153.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08155.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08157.png mask
# /content/drive/MyDrive/A3_Dataset/dataset1/annotations_prepped_test/0016E5_08159.png mask
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
result1, result2 = correct_Incorrect("Resnet50-ASPP",testing_imgs,testingy_masks,testingMsks,10)
overlay(result1, "overlayed Prediction on Testing image")
overlay(result2, "overlayed mask on Testing image")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.

# %%
result1, result2 = correct_Incorrect("Resnet50-ASPP",testing_imgs,testingy_masks,testingMsks,20)
overlay(result1, "overlayed Prediction on Testing image")
overlay(result2, "overlayed mask on Testing image")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.

# %%
result1, result2 = correct_Incorrect("Resnet50-ASPP",testing_imgs,testingy_masks,testingMsks,55)
overlay(result1, "overlayed Prediction on Testing image")
overlay(result2, "overlayed mask on Testing image")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.

# %%
result1, result2 = correct_Incorrect("Resnet50-ASPP",testing_imgs,testingy_masks,testingMsks,100)
overlay(result1, "overlayed Prediction on Testing image")
overlay(result2, "overlayed mask on Testing image")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.

# %%
testMetrics("resnet50", testing_imgs, testingy_masks)
# Out:
# average of Dice Coefficient, Sensitivity, Specificity,f1-score, iou accuracy 0.8608846605414211 0.8663795395652847 0.9892502314973586 0.8608846398863462 0.7571347656816539
